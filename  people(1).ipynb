# %% [markdown]
# 嘗試用照片來製作描邊處理

# %%
import matplotlib.pyplot as plt
import requests
import random
from PIL import Image, ImageFilter
from ipywidgets import Button,HBox,Output,Layout,Label
from IPython.display import display,clear_output


#圖檔資料
image1 = "/content/drive/MyDrive/2022Python/shawmphoto.in.pack/shawn.jpg.JPG" #shawn
image2 = "/content/drive/MyDrive/2022Python/shawmphoto.in.pack/IMG_2074.PNG"  #su

#圖檔存放位置
resimage1="/content/drive/MyDrive/2022Python/shawnresults"+"/sres1.png" #shawn
#resimage2="/content/drive/MyDrive/2022Python/shawnresults"+"/sres2.png" #su

# %%
im00 = Image.open(image1)
r=im00.filter(ImageFilter.CONTOUR)
e=r.filter(ImageFilter.CONTOUR)
s=e.filter(ImageFilter.CONTOUR) 
plt.axis("off")
_=plt.imshow(s)

# %%
im00 = Image.open(image1)
a=im00.filter(ImageFilter.EDGE_ENHANCE)
b=a.filter(ImageFilter.EDGE_ENHANCE)
c=b.filter(ImageFilter.EDGE_ENHANCE)
d=c.filter(ImageFilter.CONTOUR)
e=d.filter(ImageFilter.CONTOUR)  
f=e.filter(ImageFilter.CONTOUR)  
g=f.filter(ImageFilter.CONTOUR)  
h=g.filter(ImageFilter.CONTOUR)  
i=h.filter(ImageFilter.CONTOUR)  
plt.axis("off")
_=plt.imshow(s)

# %%
im00 = Image.open(image1)
a=im00.filter(ImageFilter.EDGE_ENHANCE)
b=a.filter(ImageFilter.EDGE_ENHANCE)
c=b.filter(ImageFilter.EDGE_ENHANCE)
d=c.filter(ImageFilter.EDGE_ENHANCE)
e=d.filter(ImageFilter.EDGE_ENHANCE)  
f=e.filter(ImageFilter.EDGE_ENHANCE)  
g=f.filter(ImageFilter.EDGE_ENHANCE)  
h=g.filter(ImageFilter.EDGE_ENHANCE)  
i=h.filter(ImageFilter.EDGE_ENHANCE)  
plt.axis("off")
_=plt.imshow(i)

# %%
im01 = Image.open(image2)
a=im01.filter(ImageFilter.EDGE_ENHANCE)
b=a.filter(ImageFilter.EDGE_ENHANCE)
c=b.filter(ImageFilter.EDGE_ENHANCE)
d=c.filter(ImageFilter.CONTOUR)
e=d.filter(ImageFilter.CONTOUR)  
f=e.filter(ImageFilter.CONTOUR)  
g=f.filter(ImageFilter.CONTOUR)  
h=g.filter(ImageFilter.CONTOUR)  
i=h.filter(ImageFilter.CONTOUR)  
plt.axis("off")
_=plt.imshow(i)

# %%
im01 = Image.open(image2)
a=im01.filter(ImageFilter.EDGE_ENHANCE)
b=a.filter(ImageFilter.EDGE_ENHANCE)
c=b.filter(ImageFilter.EDGE_ENHANCE)
d=c.filter(ImageFilter.EDGE_ENHANCE)
e=d.filter(ImageFilter.EDGE_ENHANCE)  
f=e.filter(ImageFilter.EDGE_ENHANCE)  
g=f.filter(ImageFilter.EDGE_ENHANCE)  
h=g.filter(ImageFilter.EDGE_ENHANCE)  
i=h.filter(ImageFilter.EDGE_ENHANCE)  
plt.axis("off")
_=plt.imshow(i)
