# %% [markdown]
# #日期:2022/10/31
# #姓名:謝竣翔
# #學號:a109222208

# %% [markdown]
# #連結雲端硬碟
# #路徑:檔案,連接雲端,my,sup,data01/data02

# %%
from posixpath import split
#建立基本路徑
BasePath = "/content/drive/MyDrive/SupData/"
fileName1 = BasePath+"data01.txt"
fileName2 = BasePath+"data02.txt"
#fileName1 = "/content/drive/MyDrive/SupData/data01.txt"
#開啟實體檔案,讀取資料
f = open(fileName1,"r") #以讀取的模式fileName1開啟檔案 r read
for s in f :
  w,h = map(int,s.split(",")) 
  print("體重:{}身高:{}".format(w,h))
f.close()  #關閉檔案
# Out:
# 體重:75身高:168
# 體重:62身高:152
# 體重:78身高:172
# 體重:91身高:180
# 體重:39身高:149
# 體重:43身高:159
# 體重:44身高:162
# 體重:56身高:165

# %%
#建立基本路徑
student = "/content/drive/MyDrive/SupData/student.csv"
#開啟實體檔案,讀取資料
file = open(student, "r") #以讀取的模式student開啟檔案
for s in file :
  w,h = map(int,s.split(","))
  print("體重:{}身高:{}BMI{:.2f}\n".format(w,h,w*10000/h**2))
file.close()
# Out:
# 體重:62身高:162BMI23.62
#
# 體重:46身高:156BMI18.90
#
# 體重:56身高:148BMI25.57
#
# 體重:76身高:170BMI26.30
#
# 體重:78身高:174BMI25.76
#
# 體重:56身高:176BMI18.08
#
# 體重:54身高:180BMI16.67
#
# 體重:62身高:150BMI27.56
#
# 體重:46身高:162BMI17.53
#
# 體重:56身高:156BMI23.01
#
# 體重:76身高:148BMI34.70
#
# 體重:78身高:170BMI26.99
#
# 體重:56身高:174BMI18.50
#
# 體重:54身高:176BMI17.43
#
# 體重:62身高:180BMI19.14
#
# 體重:46身高:150BMI20.44
#
# 體重:56身高:162BMI21.34
#
# 體重:76身高:156BMI31.23
#
# 體重:78身高:180BMI24.07
#
# 體重:56身高:150BMI24.89
#
# 體重:54身高:162BMI20.58
#
# 體重:62身高:156BMI25.48
#
# 體重:46身高:150BMI20.44
#
# 體重:56身高:162BMI21.34
#
# 體重:76身高:156BMI31.23
#
# 體重:78身高:148BMI35.61
#
# 體重:56身高:170BMI19.38
#
# 體重:54身高:174BMI17.84
#
# 體重:54身高:176BMI17.43
#
# 體重:62身高:180BMI19.14
#
# 體重:46身高:150BMI20.44
#
# 體重:56身高:162BMI21.34
#
# 體重:76身高:156BMI31.23
#
# 體重:78身高:148BMI35.61
#
# 體重:56身高:170BMI19.38
#
# 體重:54身高:174BMI17.84
#
# 體重:62身高:176BMI20.02
#
# 體重:46身高:180BMI14.20
#
# 體重:56身高:150BMI24.89
#
# 體重:76身高:162BMI28.96
#
# 體重:78身高:156BMI32.05
#
# ...

# %%
o = open(BasePath + "res01.tct","w")#重新建立檔案將結果寫入
with open (fileName2,"r") as f:
  for s in f:
    w,s = map(int,s.split())
    print("體重:{}身高:{}BMI{:.2f}\n".format(w,h,w*10000/h**2))
    o.write("體重:{}身高:{}BMI{:.2f}\n".format(w,h,w*10000/h**2))
o.close()
# Out:
# 體重:75身高:165BMI27.55
#
# 體重:62身高:165BMI22.77
#
# 體重:78身高:165BMI28.65
#
# 體重:91身高:165BMI33.43
#
# 體重:39身高:165BMI14.33
#
# 體重:43身高:165BMI15.79
#
# 體重:44身高:165BMI16.16
#
# 體重:56身高:165BMI20.57
# <function TextIOWrapper.close()>
