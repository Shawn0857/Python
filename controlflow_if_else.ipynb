# %%
#日期:2022/10/17
#姓名:謝竣翔
#學號:A109222208

# %%
#計算BMI
height = float(input("輸入身高(公尺):"))
weight = float(input("輸入體重(公斤):"))
bmi = height/height/weight
print("BMI為{:10.2f}".format(bmi))
if bmi >= 35:
  print("重度肥胖")

# %%
#危險指數

c = float(input("室外溫度:"))
h = float(input("室外相對溼度:"))
d = c+h*0.1
print("室外溫度:{:10.2f},室外相對溼度:{:10.2f},危險係數{:10.2f}".format(c,h,d))
if d >=38:
  print("禁止外出操課")
else:
  print("可以外出操課")
# Out:
# 室外溫度:25
# 室外相對溼度:90
#      25.00     90.00     34.00
# 可以外出操課

# %%
#隨機亂數分組(偶數為第一隊,基數為第二隊)
import random
號碼 = random.randint(1,20)
隊伍=1 if 號碼%2 ==0 else 2
print("號碼{},第{}隊".format(號碼,隊伍))

# %%
#成績分數轉等地
score = float(input("輸入一個學生分數(0~100):"))
if score<0 or score>100:
  print("輸入範圍錯誤")
else:
  if 90<=score:
    print("A")
  elif 80<=score and score<90:
    print("B")
  elif 70<=score and score<80:
    print("C")
  elif 60<=score and score<70:
    print("D")
  else:
    print("E")
# Out:
# 輸入一個學生分數(0~100):99
# A

# %%
#中央氣象局颱風
#最大颱風速設A
A = int(input("輸入中心最大風速(整數):"))
if A>=184 :
  print("強烈颱風")
else:
  if 183<A and A<=118 :
    print("中度颱風")
  elif 62<=A and A<117 :
    print("輕度颱風")
  elif A<62  :
    print("尚未到達颱風範圍")

# %%
#第108頁 第8題
#設長寬高 length , width , height
length = float(input("輸入中心最大風速(整數):"))
width = float(input("輸入中心最大風速(整數):"))
height = float(input("輸入中心最大風速(整數):"))
if length+width>height && length+height>width height+width>length:   #(是三角形,那是甚麼三角形)
 
else:
  print("不是三角形")
# Out:
#   File "<ipython-input-1-65bffd8c8c02>", line 6
#     if length+width>height && length+height>width height+width>length:   #(是三角形,那是甚麼三角形)
#                             ^
# SyntaxError: invalid syntax
